# %%
from decouple import config

# %%
assert config("ALPHA_VANTAGE_API_KEY", default=None, cast=str) is not None

# %%
ALPHA_VANTAGE_API_KEY = config("ALPHA_VANTAGE_API_KEY", default=None, cast=str)

# %%
from datetime import datetime
import pytz
from decimal import Decimal

def transform_alpha_vantage_result(timestamp_str, result_val):
    #unix_timestamp = result.get('t')/1000
    #utc_timestamp = datetime.fromtimestamp(unix_timestamp, tz=pytz.timezone("UTC"))
    #print(utc_timestamp)
    timestamp_format = "%Y-%m-%d %H:%M:%S"
    eastern = pytz.timezone("US/Eastern")
    utc = pytz.utc
    timestamp = eastern.localize(datetime.strptime(timestamp_str, timestamp_format)).astimezone(utc)
    # timestamp
    return{
        "open_price" : Decimal(result_val["1. open"]),
        "close_price" : Decimal(result_val["4. close"]),
        "high_price" : Decimal(result_val["2. high"]),
        "low_price" : Decimal(result_val["3. low"]),
        "number_of_trades" : None,
        "volume" : int(result_val["5. volume"]),
        "volume_weighted_average" : None,
        "time" : timestamp,
    }

# %%
from dataclasses import dataclass
from typing import Literal
from urllib.parse import urlencode
import requests

ALPHA_VANTAGE_API_KEY = config("ALPHA_VANTAGE_API_KEY", default=None, cast=str)

@dataclass
class AlphaVantageAPIClient:
    ticker: str = "AAPL"  # company's symbol in stocks
    api_key: str = ""
    function: Literal["TIME_SERIES_INTRADAY"] = "TIME_SERIES_INTRADAY"
    interval: Literal["1min", "5min", "15min", "30min", "60min"] = "1min"
    month: str = "2024-11"
    

    def get_api_key(self):
        return self.api_key or ALPHA_VANTAGE_API_KEY
    
    def get_headers(self):
        api_key = self.get_api_key()
        return {}

    def get_params(self):
        return {
            "apikey" : self.get_api_key(),
            "symbol" : self.ticker,
            "function" : self.function,
            "interval" : self.interval,
            "month" : self.month
        }

    def generate_url(self, pass_auth=False):
        path = "/query"
        url = f"https://www.alphavantage.co{path}"
        params = self.get_params()
        encoded_params = urlencode(params)
        url = f"{url}?{encoded_params}"
        if pass_auth:
            api_key = self.get_api_key()
            url += f"&apiKey={api_key}"
        return url

    def fetch_data(self):
        headers = self.get_headers()
        url = self.generate_url()
        response = requests.get(url, headers=headers)
        response.raise_for_status() # not 200/201. Incase there is an error
        return response.json()

    def get_stock_data(self):
        data = self.fetch_data()
        dataset_key = [x for x in list(data.keys()) if not x.lower() == "meta data"][0]
        results = data[dataset_key]  # dictionary
        dataset = []
        for timestamp_str in results.keys():
            dataset.append(
                transform_alpha_vantage_result(timestamp_str, results.get(timestamp_str))
            )
        return dataset

# %%
stock_api_client = AlphaVantageAPIClient()
dataset = stock_api_client.get_stock_data()
dataset
# Out:
# [{'open_price': Decimal('237.3600'),
#   'close_price': Decimal('237.4450'),
#   'high_price': Decimal('237.4900'),
#   'low_price': Decimal('237.3600'),
#   'number_of_trades': None,
#   'volume': 616,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3750'),
#   'close_price': Decimal('237.3600'),
#   'high_price': Decimal('237.4900'),
#   'low_price': Decimal('237.3535'),
#   'number_of_trades': None,
#   'volume': 598,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.3750'),
#   'high_price': Decimal('237.3987'),
#   'low_price': Decimal('237.3000'),
#   'number_of_trades': None,
#   'volume': 339,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3250'),
#   'close_price': Decimal('237.3000'),
#   'high_price': Decimal('237.3900'),
#   'low_price': Decimal('237.3000'),
#   'number_of_trades': None,
#   'volume': 5383,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3700'),
#   'close_price': Decimal('237.3300'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.3000'),
#   'number_of_trades': None,
#   'volume': 43,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4000'),
#   'close_price': Decimal('237.3250'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3000'),
#   'number_of_trades': None,
#   'volume': 1252,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3150'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3000'),
#   'number_of_trades': None,
#   'volume': 626,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3400'),
#   'close_price': Decimal('237.3300'),
#   'high_price': Decimal('237.3650'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 1934,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3700'),
#   'close_price': Decimal('237.3497'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 3816,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3850'),
#   'close_price': Decimal('237.3850'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3700'),
#   'number_of_trades': None,
#   'volume': 12,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4000'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.3850'),
#   'number_of_trades': None,
#   'volume': 142,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4500'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.5000'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 3368,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4500'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.5000'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 89,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4450'),
#   'close_price': Decimal('237.5000'),
#   'high_price': Decimal('237.5000'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 111,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4994'),
#   'close_price': Decimal('237.4800'),
#   'high_price': Decimal('237.5000'),
#   'low_price': Decimal('237.3900'),
#   'number_of_trades': None,
#   'volume': 570,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4900'),
#   'close_price': Decimal('237.4800'),
#   'high_price': Decimal('237.5000'),
#   'low_price': Decimal('237.4800'),
#   'number_of_trades': None,
#   'volume': 853,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4600'),
#   'close_price': Decimal('237.4800'),
#   'high_price': Decimal('237.4900'),
#   'low_price': Decimal('237.4300'),
#   'number_of_trades': None,
#   'volume': 149,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4800'),
#   'close_price': Decimal('237.4600'),
#   'high_price': Decimal('237.4900'),
#   'low_price': Decimal('237.4315'),
#   'number_of_trades': None,
#   'volume': 68,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4400'),
#   'close_price': Decimal('237.4800'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.4300'),
#   'number_of_trades': None,
#   'volume': 1465,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4100'),
#   'close_price': Decimal('237.4300'),
#   'high_price': Decimal('237.4400'),
#   'low_price': Decimal('237.4100'),
#   'number_of_trades': None,
#   'volume': 688,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4150'),
#   'close_price': Decimal('237.4100'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 32,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4200'),
#   'close_price': Decimal('237.4300'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3900'),
#   'number_of_trades': None,
#   'volume': 156,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4000'),
#   'close_price': Decimal('237.4100'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3900'),
#   'number_of_trades': None,
#   'volume': 318,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4000'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3900'),
#   'number_of_trades': None,
#   'volume': 131,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3950'),
#   'close_price': Decimal('237.3600'),
#   'high_price': Decimal('237.4700'),
#   'low_price': Decimal('237.3600'),
#   'number_of_trades': None,
#   'volume': 112,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4100'),
#   'close_price': Decimal('237.3950'),
#   'high_price': Decimal('237.4282'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 122,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4100'),
#   'close_price': Decimal('237.4100'),
#   'high_price': Decimal('237.4400'),
#   'low_price': Decimal('237.3900'),
#   'number_of_trades': None,
#   'volume': 52,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.4100'),
#   'high_price': Decimal('237.4100'),
#   'low_price': Decimal('237.3900'),
#   'number_of_trades': None,
#   'volume': 449,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.4100'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3900'),
#   'number_of_trades': None,
#   'volume': 135,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3600'),
#   'close_price': Decimal('237.3600'),
#   'high_price': Decimal('237.3900'),
#   'low_price': Decimal('237.3600'),
#   'number_of_trades': None,
#   'volume': 17,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4300'),
#   'close_price': Decimal('237.3600'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 25,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4000'),
#   'close_price': Decimal('237.4300'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3800'),
#   'number_of_trades': None,
#   'volume': 149,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4100'),
#   'close_price': Decimal('237.3500'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 331,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.3900'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 490,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.3500'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 233,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4000'),
#   'close_price': Decimal('237.3500'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 375,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.4200'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 431,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.3900'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 37,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.3900'),
#   'high_price': Decimal('237.3900'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 86,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3900'),
#   'close_price': Decimal('237.3700'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3501'),
#   'number_of_trades': None,
#   'volume': 592,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3800'),
#   'close_price': Decimal('237.3900'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3700'),
#   'number_of_trades': None,
#   'volume': 217,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 19, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3700'),
#   'close_price': Decimal('237.3800'),
#   'high_price': Decimal('237.3900'),
#   'low_price': Decimal('237.3600'),
#   'number_of_trades': None,
#   'volume': 340,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 18, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3700'),
#   'close_price': Decimal('237.3700'),
#   'high_price': Decimal('237.3900'),
#   'low_price': Decimal('237.3700'),
#   'number_of_trades': None,
#   'volume': 38,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 17, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3850'),
#   'close_price': Decimal('237.3850'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3700'),
#   'number_of_trades': None,
#   'volume': 181,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 16, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3850'),
#   'close_price': Decimal('237.3900'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3700'),
#   'number_of_trades': None,
#   'volume': 46,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4000'),
#   'close_price': Decimal('237.3850'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3700'),
#   'number_of_trades': None,
#   'volume': 391,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 14, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4300'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3700'),
#   'number_of_trades': None,
#   'volume': 25,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 13, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3950'),
#   'close_price': Decimal('237.3700'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3600'),
#   'number_of_trades': None,
#   'volume': 86,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 12, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3950'),
#   'close_price': Decimal('237.4300'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3600'),
#   'number_of_trades': None,
#   'volume': 189,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 11, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4000'),
#   'close_price': Decimal('237.4200'),
#   'high_price': Decimal('237.4200'),
#   'low_price': Decimal('237.3400'),
#   'number_of_trades': None,
#   'volume': 289,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3300'),
#   'close_price': Decimal('237.3750'),
#   'high_price': Decimal('237.4200'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 256,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 9, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3800'),
#   'close_price': Decimal('237.3400'),
#   'high_price': Decimal('237.4100'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 119,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 8, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3850'),
#   'close_price': Decimal('237.3800'),
#   'high_price': Decimal('237.4372'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 91,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 7, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3600'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.4399'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 2426,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 6, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3500'),
#   'close_price': Decimal('237.3850'),
#   'high_price': Decimal('237.4400'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 141,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3300'),
#   'close_price': Decimal('237.3300'),
#   'high_price': Decimal('237.4400'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 2497,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 4, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3400'),
#   'close_price': Decimal('237.3600'),
#   'high_price': Decimal('237.3850'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 821,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 3, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3500'),
#   'close_price': Decimal('237.3500'),
#   'high_price': Decimal('237.3950'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 727,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 2, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3950'),
#   'close_price': Decimal('237.3300'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 25083,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 1, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3300'),
#   'close_price': Decimal('237.4300'),
#   'high_price': Decimal('237.4400'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 573,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 21, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3300'),
#   'close_price': Decimal('237.3850'),
#   'high_price': Decimal('237.5000'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 910,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4400'),
#   'close_price': Decimal('237.3300'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 5505,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3300'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 101,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4100'),
#   'close_price': Decimal('237.4050'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.4050'),
#   'number_of_trades': None,
#   'volume': 155,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4500'),
#   'close_price': Decimal('237.4800'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 5626,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3300'),
#   'close_price': Decimal('237.4000'),
#   'high_price': Decimal('237.4700'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 1827,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3500'),
#   'close_price': Decimal('237.3700'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 93,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.2950'),
#   'close_price': Decimal('237.3500'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.2800'),
#   'number_of_trades': None,
#   'volume': 666,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.2950'),
#   'close_price': Decimal('237.2800'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.2200'),
#   'number_of_trades': None,
#   'volume': 90,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3250'),
#   'close_price': Decimal('237.3000'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.2200'),
#   'number_of_trades': None,
#   'volume': 2149,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.2800'),
#   'close_price': Decimal('237.2900'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.2800'),
#   'number_of_trades': None,
#   'volume': 101,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3000'),
#   'close_price': Decimal('237.3250'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.2200'),
#   'number_of_trades': None,
#   'volume': 1255,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3600'),
#   'close_price': Decimal('237.3350'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.2200'),
#   'number_of_trades': None,
#   'volume': 106,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.2950'),
#   'close_price': Decimal('237.2300'),
#   'high_price': Decimal('237.3000'),
#   'low_price': Decimal('237.2200'),
#   'number_of_trades': None,
#   'volume': 157,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.2200'),
#   'close_price': Decimal('237.2237'),
#   'high_price': Decimal('237.3700'),
#   'low_price': Decimal('237.2200'),
#   'number_of_trades': None,
#   'volume': 19,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.2800'),
#   'close_price': Decimal('237.2950'),
#   'high_price': Decimal('237.3800'),
#   'low_price': Decimal('237.2200'),
#   'number_of_trades': None,
#   'volume': 4368,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3400'),
#   'close_price': Decimal('237.2900'),
#   'high_price': Decimal('237.3400'),
#   'low_price': Decimal('237.2700'),
#   'number_of_trades': None,
#   'volume': 2209,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3800'),
#   'close_price': Decimal('237.3800'),
#   'high_price': Decimal('237.4000'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 1465,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3400'),
#   'close_price': Decimal('237.4300'),
#   'high_price': Decimal('237.4300'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 2196,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3800'),
#   'close_price': Decimal('237.3800'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.3400'),
#   'number_of_trades': None,
#   'volume': 788,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4050'),
#   'close_price': Decimal('237.3900'),
#   'high_price': Decimal('237.4700'),
#   'low_price': Decimal('237.3400'),
#   'number_of_trades': None,
#   'volume': 613,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4500'),
#   'close_price': Decimal('237.4050'),
#   'high_price': Decimal('237.4700'),
#   'low_price': Decimal('237.3800'),
#   'number_of_trades': None,
#   'volume': 1190,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4500'),
#   'close_price': Decimal('237.4500'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.4300'),
#   'number_of_trades': None,
#   'volume': 420,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4700'),
#   'close_price': Decimal('237.4500'),
#   'high_price': Decimal('237.4700'),
#   'low_price': Decimal('237.3800'),
#   'number_of_trades': None,
#   'volume': 89,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4100'),
#   'close_price': Decimal('237.4300'),
#   'high_price': Decimal('237.4700'),
#   'low_price': Decimal('237.3530'),
#   'number_of_trades': None,
#   'volume': 83,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4150'),
#   'close_price': Decimal('237.3530'),
#   'high_price': Decimal('237.4700'),
#   'low_price': Decimal('237.3512'),
#   'number_of_trades': None,
#   'volume': 157,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3500'),
#   'close_price': Decimal('237.4767'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 20,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4150'),
#   'close_price': Decimal('237.4150'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 566,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4100'),
#   'close_price': Decimal('237.4150'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3500'),
#   'number_of_trades': None,
#   'volume': 149,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4250'),
#   'close_price': Decimal('237.3500'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3400'),
#   'number_of_trades': None,
#   'volume': 314,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4100'),
#   'close_price': Decimal('237.4250'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3400'),
#   'number_of_trades': None,
#   'volume': 72,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.3400'),
#   'close_price': Decimal('237.4100'),
#   'high_price': Decimal('237.4800'),
#   'low_price': Decimal('237.3300'),
#   'number_of_trades': None,
#   'volume': 181,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4200'),
#   'close_price': Decimal('237.4050'),
#   'high_price': Decimal('237.4600'),
#   'low_price': Decimal('237.3700'),
#   'number_of_trades': None,
#   'volume': 558,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4450'),
#   'close_price': Decimal('237.4450'),
#   'high_price': Decimal('237.4900'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 55,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4450'),
#   'close_price': Decimal('237.4500'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 34,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4500'),
#   'close_price': Decimal('237.4450'),
#   'high_price': Decimal('245.0148'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 920,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4500'),
#   'close_price': Decimal('237.4500'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 132,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4350'),
#   'close_price': Decimal('237.4250'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.4000'),
#   'number_of_trades': None,
#   'volume': 98,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4400'),
#   'close_price': Decimal('237.4500'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.4200'),
#   'number_of_trades': None,
#   'volume': 173,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('237.4300'),
#   'close_price': Decimal('237.4350'),
#   'high_price': Decimal('237.4500'),
#   'low_price': Decimal('237.4200'),
#   'number_of_trades': None,
#   'volume': 288,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 11, 29, 20, 20, tzinfo=<UTC>)}]
